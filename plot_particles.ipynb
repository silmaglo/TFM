# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/gpfs/users/lopezs'

# %%
cd data/CCDimg
# Out:
# /gpfs/users/lopezs/data/CCDimg

# %%
electron = np.load("AncientLead_PV_208a81z_s82_N100000_image_evt_10123_ccd_1_ind_0_pdg_11.npz")

# %%
fig = plt.figure(figsize=(30,30))
plt.imshow(electron['noise'], cmap='Reds')
plt.colorbar()

# %%
import os
#my_path = os.path.abspath(__file__) 
# Figures out the absolute path for you in case your working directory moves around.
myPath = '/gpfs/users/lopezs/data/plots_particles'
fig.savefig(myPath + '/plot_noise_electron.png')

# %%
fig = plt.figure(figsize=(30,30))
plt.imshow(electron['energy'], cmap='Reds')
plt.colorbar()
fig.savefig(myPath + '/plot_energy_electron.png')

# %%
alpha = np.load("CCDSensor_PV_210a84z_s1_N50_image_evt_1_ccd_1_ind_0_pdg_1000020040.npz")

# %%
fig = plt.figure(figsize=(30,30))
plt.imshow(alpha['noise'], cmap='Reds')
plt.colorbar()
fig.savefig(myPath + '/plot_noise_alpha.png')

# %%
fig = plt.figure(figsize=(30,30))
plt.imshow(alpha['energy'], cmap='Reds')
plt.colorbar()
fig.savefig(myPath + '/plot_energy_alpha.png')

# %%
alpha2 = np.load("CCDSensor_PV_210a84z_s1_N50_image_evt_11_ccd_2_ind_0_pdg_1000020040.npz")

# %%
fig = plt.figure(figsize=(30,30))
plt.imshow(alpha2['noise'], cmap='Reds')
plt.colorbar()
fig.savefig(myPath + '/plot_noise_alpha2.png')

# %%
fig = plt.figure(figsize=(30,30))
plt.imshow(alpha2['energy'], cmap='Reds')
plt.colorbar()
fig.savefig(myPath + '/plot_energy_alpha2.png')

# %%
gamma = np.load("AncientLead_PV_208a81z_s82_N100000_image_evt_77859_ccd_2_ind_0_pdg_22.npz")

# %%
fig = plt.figure(figsize=(30,30))
plt.imshow(gamma['noise'], cmap='Reds')
plt.colorbar()
fig.savefig(myPath + '/plot_noise_gamma.png')

# %%
fig = plt.figure(figsize=(30,30))
plt.imshow(gamma['energy'], cmap='Reds')
plt.colorbar()
fig.savefig(myPath + '/plot_energy_gamma.png')
